# %% [markdown]
# This notebook removes extraneous fields and adds timestamps.

# %%
pwd
# Out:
# '/Users/peterhaglich/Dropbox/Work/IARPA/Mercury/peterhaglich/mercury-challenge/src/Baserate/notebooks'

# %%
import os
import json
import re
from numpy.random import (
  choice,
  poisson,
  uniform
)
import datetime
from dateutil.parser import parse

# %%
LT_MEAN = 3
def pad_timestamp(ts_str):
    """
    Adds Hour/Minute/Second/Fraction data to the timestamp
    :param ts_str: The string in format "%Y-%m-%d"
    :return: String with format '%Y-%m-%dT%H:%M:%S.%f'
    """
    hours = choice(range(24), 1)[0]
    minutes, seconds = choice(range(60), 2)
    out_str = "{0}T{1}:{2}:{3}.0".format(ts_str, hours, minutes, seconds)
    return out_str

def construct_timestamp(event_date, assumed_leadtime=LT_MEAN):
    """
    Constructs a timestamp given predicted event date and an assumed lead time
    """
    event_dtg = parse(event_date)
    send_dtg = event_dtg - datetime.timedelta(days=LT_MEAN+1)
    send_str = send_dtg.strftime("%Y-%m-%d")
    send_str = pad_timestamp(send_str)
    return send_str

# %%
test_date = "2018-08-13"
construct_timestamp(test_date)
# Out:
# '2018-08-09T0:28:30.0'

# %%
MC_HOME = os.path.abspath("../../..")
DATA_PATH = os.path.join(MC_HOME, "data")
WARN_PATH = os.path.join(DATA_PATH, "baserate_warnings")
CU_WARN_PATH = os.path.join(WARN_PATH, "baserate_cu_warnings")
DIS_WARN_PATH = os.path.join(WARN_PATH, "baserate_disease_warnings")
cu_places = [x for x in os.listdir(CU_WARN_PATH) if x != ".DS_Store"]
cu_places
# Out:
# ['Amman', 'Tahrir', 'Irbid', 'Egypt', 'Madaba', 'Jordan']

# %%
for place in ["Egypt"]:
    print(place)
    place_path = os.path.join(CU_WARN_PATH, place)
    warn_files = [x for x in os.listdir(place_path) if x.endswith("json")]
    for wf in warn_files:
        wf_path = os.path.join(place_path, wf)
        with open(wf_path, "r", encoding="utf-8-sig") as f:
            warn_dict = json.load(f)
        print("Before")
        print(warn_dict)
        payload=warn_dict["payload"]
        print("After")
        for w in payload:
            try:
                del(w["Model_Details"])
            except KeyError:
                pass
            w["timestamp"] = construct_timestamp(w["Event_Date"])
            
        with open(wf_path, "w") as f:
            json.dump(warn_dict, f, ensure_ascii=False)
# Out:
# Egypt
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-01', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-01'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-02', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-02'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-03', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-03'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-04', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-04'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-05', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-05'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-06', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-06'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-07', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-07'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-08', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-08'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-09', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-09'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-10', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-10'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-11', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-11'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-12', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-12'}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-13', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-14', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-14', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-15', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-15', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-16', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-16', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-17', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-17', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-18', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-18', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-19', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-19', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-01-20', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-01-20', ' ...
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-01', 'Case_Count': 12.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-01', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-02', 'Case_Count': 6.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-02', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-03', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-03', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-04', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-04', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-05', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-05', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-06', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-06', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-07', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-07', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-08', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-08', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-09', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-09', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-10', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-10', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-11', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-11', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-12', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-12', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-03-13', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-03-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], ' ...
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-01', 'Case_Count': 1.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-01', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-02', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-02', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-03', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-03', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-04', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-04', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-05', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-05', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-06', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-06', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-07', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-07', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-08', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-08', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-09', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-09', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-10', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-10', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-11', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-11', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-12', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-12', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-06-13', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-06-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'E ...
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-01', 'Case_Count': 3.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-01', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-02', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-02', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-03', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-03', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-04', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-04', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-05', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-05', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-06', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-06', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-07', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-07', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-08', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-08', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-09', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-09', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-10', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-10', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-11', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-11', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-12', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-12', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-02-13', 'Case_Count': 2.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-02-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'E ...
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-01', 'Case_Count': 13.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-01', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-02', 'Case_Count': 17.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-02', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-03', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-03', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-04', 'Case_Count': 19.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-04', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-05', 'Case_Count': 19.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-05', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-06', 'Case_Count': 19.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-06', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-07', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-07', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-08', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-08', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-09', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-09', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-10', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-10', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-11', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-11', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-12', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-12', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-04-13', 'Case_Count': 18.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-04-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.88889259 ...
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-01', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-01', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-02', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-02', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-03', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-03', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-04', 'Case_Count': 4.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-04', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-05', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-05', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-06', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-06', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-07', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-07', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-08', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-08', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-09', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-09', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-10', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-10', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-11', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-11', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-12', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-12', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'Error': 0.4152948681735336}}, {'Event_Type': 'Civil Unrest', 'Event_Date': '2018-05-13', 'Case_Count': 5.0, 'Country': 'Egypt', 'Warning_ID': 'BR_CU_Egypt_2018-05-13', 'Model_Details': {'Order': [2, 0, 1], 'Model_Params': [5.348368567013427, 1.3043697162287806, -0.3267554866621827, -0.8888925988013819], 'E ...
# After

# %%
dis_warn_files = [x for x in os.listdir(DIS_WARN_PATH) if x.endswith("json")]
for wf in dis_warn_files:
    wf_path = os.path.join(DIS_WARN_PATH, wf)
    with open(wf_path, "r", encoding="utf-8-sig") as f:
        warn_dict = json.load(f)
    print("Before")
    print(warn_dict)
    payload=warn_dict["payload"]
    print("After")
    for w in payload:
        del(w["Model_Details"])
        w["timestamp"] = construct_timestamp(w["Event_Date"])

    with open(wf_path, "w") as f:
        json.dump(warn_dict, f, ensure_ascii=False)
# Out:
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-02-04', 'Case_Count': 0.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-02-04', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-02-11', 'Case_Count': 0.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-02-11', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-02-18', 'Case_Count': 0.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-02-18', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-02-25', 'Case_Count': 0.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-02-25', 'Model_Details': 'Historical Average Model'}]}
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-05-06', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-05-06', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-05-13', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-05-13', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-05-20', 'Case_Count': 1.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-05-20', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-05-27', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-05-27', 'Model_Details': 'Historical Average Model'}]}
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-04-01', 'Case_Count': 4.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-04-01', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-04-08', 'Case_Count': 3.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-04-08', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-04-15', 'Case_Count': 3.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-04-15', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-04-22', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-04-22', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-04-29', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-04-29', 'Model_Details': 'Historical Average Model'}]}
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-03-04', 'Case_Count': 7.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-03-04', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-03-11', 'Case_Count': 7.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-03-11', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-03-18', 'Case_Count': 14.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-03-18', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-03-25', 'Case_Count': 17.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-03-25', 'Model_Details': 'Historical Average Model'}]}
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-01-07', 'Case_Count': 1.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-01-07', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-01-14', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-01-14', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-01-21', 'Case_Count': 2.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-01-21', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-01-28', 'Case_Count': 3.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-01-28', 'Model_Details': 'Historical Average Model'}]}
# After
# Before
# {'participant_id': 'Mercury_Baserate', 'payload': [{'Event_Type': 'Disease', 'Event_Date': '2018-06-03', 'Case_Count': 18.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-06-03', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-06-10', 'Case_Count': 15.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-06-10', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-06-17', 'Case_Count': 5.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-06-17', 'Model_Details': 'Historical Average Model'}, {'Event_Type': 'Disease', 'Event_Date': '2018-06-24', 'Case_Count': 9.0, 'Country': 'Saudi Arabia', 'Warning_ID': 'BR_CU_MERS_2018-06-24', 'Model_Details': 'Historical Average Model'}]}
# After
